# %% [markdown]
# <a href="https://colab.research.google.com/github/janko0823/2020-2-AI/blob/master/code/06_neuron_activation_dense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.e
# Out:
# 2.718281828459045

# %%
import numpy as np
import matplotlib.pylab as plt

plt.figure(figsize=(6, 4))
x = np.linspace(-8, 8, 100) #-8에서 8까지 100등분
plt.plot(x, np.exp(-x), 'b--')
_=plt.plot(x, np.exp(x), 'r--')

# %%
import numpy as np
import matplotlib.pylab as plt

def sigm_func(x): #sigmod 함수
    return 1 / (1 + np.exp(-x))

#시그모이드 함수 그리기
plt.figure(figsize=(8, 6))
x = np.linspace(-8, 8, 100) #-8에서 8까지 100등분
plt.plot(x, sigm_func(-x), 'b--')

# %%
import numpy as np
import matplotlib.pylab as plt

def relu_func(x): #ReLU (정류화된 선형 유닛) 함수
    return np.maximum(0,x)

#ReLU함수 그리기
plt.figure(figsize=(8, 6))
x = np.linspace(-8, 8, 100)
plt.plot(x, relu_func(x))

# %%
import numpy as np
import matplotlib.pylab as plt

def relu_func(x): #ReLU (정류화된 선형 유닛) 함수
    return np.maximum(0,x)

def sigm_func(x): #sigmod 함수
    return 1 / (1 + np.exp(-x))

plt.figure(figsize=(8, 6))
x = np.linspace(-4, 4, 100)
y = np.linspace(-0.2, 2, 100)

plt.plot(x, relu_func(x), linestyle=':', label="ReLU")
plt.plot(x, sigm_func(x), linestyle='--', label="sigmoid")
plt.legend(loc='upper left')

# %%
import numpy as np
import matplotlib.pylab as plt

def identity_func(x): #항등함수
    return x

def linear_func(x): #1차함수
    return 1.5 * x + 1 # a기울기(1.5), Y절편b(1) 조절가능

def tanh_func(x): #tanh함수
    return np.tanh(x)

def relu_func(x): #ReLU 함수
    return np.maximum(0, x)

def sigm_func(x): #sigmoid함수
    return 1 / (1 + np.exp(-x))

#그래프 그리기
plt.figure(figsize=(12, 8))
x = np.linspace(-2, 4, 100)
plt.plot(x, identity_func(x), linestyle='--', label="identity")
plt.plot(x, linear_func(x), linestyle=':', label="linear")
plt.plot(x, tanh_func(x), linestyle='-.', label="tanh")
plt.plot(x, relu_func(x), linestyle='-', label="ReLU")
plt.plot(x, sigm_func(x), linestyle='--', label="sigmoid")
plt.legend(loc="upper left")

# %%
import tensorflow as tf

x = [[1,2]]
w = [[1, 2, 3], [4, 5, 6]]

y = tf.matmul(x, w)
y.numpy()
# Out:
# array([[ 9, 12, 15]], dtype=int32)

# %%
x = [[6, 5]]
w = [[1, 2, 3], [4, 5, 6]]

y = tf.matmul(x, w)
y.numpy()
# Out:
# array([[26, 37, 48]], dtype=int32)

# %%
x = [[6, 5], [4, 7], [5, 6], [6, 7]]
w = [[1, 2, 3], [4, 5, 6]]

y = tf.matmul(x, w)
y.numpy()
# Out:
# array([[26, 37, 48],
#        [32, 43, 54],
#        [29, 40, 51],
#        [34, 47, 60]], dtype=int32)

# %%
w = [[1, 4],[2, 5],[3, 6]]
x = [[6, 4, 5, 6], [5, 7, 6, 7]]

y = tf.matmul(w, x)
y.numpy
# Out:
# <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(3, 4), dtype=int32, numpy=
# array([[26, 32, 29, 34],
#        [37, 43, 40, 47],
#        [48, 54, 51, 60]], dtype=int32)>>

# %%
# tf.keras 를 이용한 AND 네트워크 계산
import numpy as np
x = np.array([[1,1],[1,0],[0,1],[0,0]])
y = np.array([[1], [0], [0], [0]])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, activation='sigmoid', input_shape=(2,)),                                                          
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, y, epochs=400, batch_size=1)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2628
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2459
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2324
# Epoch 4/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2224
# Epoch 5/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2134
# Epoch 6/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2050
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1989
# Epoch 8/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1927
# Epoch 9/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1872
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1819
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1772
# Epoch 12/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1725
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model.predict(x)
# Out:
# array([[0.85613346],
#        [0.12098923],
#        [0.12093851],
#        [0.00317201]], dtype=float32)

# %%
for weight in model.weights:
    print(weight)
# Out:
# <tf.Variable 'dense/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[3.767112 ],
#        [3.7666352]], dtype=float32)>
# <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([-5.7502074], dtype=float32)>

# %%
model.weights[0]
# Out:
# <tf.Variable 'dense/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[3.767112 ],
#        [3.7666352]], dtype=float32)>

# %%
model.weights[1]
# Out:
# <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([-5.7502074], dtype=float32)>

# %%
import numpy as np
x = np.array([[1,1],[1,0],[0,1],[0,0]])
y = np.array([[1],[1],[1],[0]])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, activation='sigmoid', input_shape=(2,))                             
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3), loss='mse')
model.summary()

history = model.fit(x, y, epochs=400, batch_size=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2460
# Epoch 2/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2058
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1815
# Epoch 4/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1663
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1557
# Epoch 6/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1483
# Epoch 7/400
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1427
# Epoch 8/400
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model.predict(x)
# Out:
# array([[0.999073  ],
#        [0.9246626 ],
#        [0.924777  ],
#        [0.12280741]], dtype=float32)

# %%
for weight in model.weights:
  print(weight)
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[4.4735613],
#        [4.4752035]], dtype=float32)>
# <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-1.966109], dtype=float32)>

# %%
import numpy as np
x = np.array([[1,1],[1,0],[0,1],[0,0]])
y = np.array([[1],[1],[1],[0]])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=2, activation='sigmoid', input_shape=(2,)),
    tf.keras.layers.Dense(units=1, activation='sigmoid')                             
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3), loss='mse')

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, y, epochs=1500, batch_size=1)
# Out:
# Epoch 1/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3127
# Epoch 2/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2770
# Epoch 3/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 4/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2330
# Epoch 5/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2201
# Epoch 6/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2116
# Epoch 7/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2053
# Epoch 8/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2009
# Epoch 9/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1970
# Epoch 10/1500
# 4/4 [==============================] - 0s 965us/step - loss: 0.1943
# Epoch 11/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1924
# Epoch 12/1500
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model.predict(x)
# Out:
# array([[0.9875769],
#        [0.9709047],
#        [0.9686781],
#        [0.0358977]], dtype=float32)

# %%
# xor 네트워크의 가중치와 판향 확인
for weight
# Out:
#   File "<ipython-input-26-6cda67573830>", line 2
#     for weight
#               ^
# SyntaxError: invalid syntax

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

dv = webdriver.Chrome('C:/chromedriver.exe')
dv.get("http://www.naver.com")

elem = dv.find_element_by_name("query")
elem.send_keys("맞춤법 검사기")
elem.send_keys(Keys.RETURN)

time.sleep(2)
elem = dv.find_element_by_class_name("txt_gray")
elem.send_keys("안녕하세요 반갑숩니다")

elem = dv.find_element_by_class_name("btn_check")
elem.click()

time.sleep(1)

soup = BeautifulSoup(dv.page_source, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-182741de8e0c> in <module>()
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.common.keys import Keys
#       3 import time
#       4 from bs4 import BeautifulSoup
#       5
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
print(soup.select("p._result_text.stand_txt"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-9823e1b70a9e> in <module>()
# ----> 1 print(soup.select("p._result_text.stand_txt"))
#
# NameError: name 'soup' is not defined
